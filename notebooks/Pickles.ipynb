# %%
from scripts.classes import *
from IPython.display import display
import os
import pickle

os.chdir('..')
print(os.getcwd())
# Out:
# /Users/michaelhofer/Documents/GitHub/NeuronVisualizer2.0

# %%
data = []
worms = 5

# %%
for i in range(worms):
    with open(f'data/pickles/data_worm_{i + 1}_8D.pkl', 'rb') as file:
        loaded_data = pickle.load(file)
        loaded_data.behavioral_state_diagram(cog_stat_num=2, save=False)
        loaded_data.step_plot(clusters=3)
# Out:
# threshold is:  0.001
# threshold is:  0.001
# threshold is:  0.001
# threshold is:  0.001
# threshold is:  0.001

# %%
worm = 1

# %%
with open(f'data/pickles/data_worm_{worm}_8D.pkl', 'rb') as file:
    loaded_data = pickle.load(file)
    loaded_data.behavioral_state_diagram(interactive=True, cog_stat_num=1)
    loaded_data.step_plot(clusters=3)
# Out:
# threshold is:  0.002
# data/plots/.html
